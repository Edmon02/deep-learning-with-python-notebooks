# %% [markdown]
# This is a companion notebook for the book [Deep Learning with Python, Second Edition](https://www.manning.com/books/deep-learning-with-python-second-edition?a_aid=keras&a_bid=76564dff). For readability, it only contains runnable code blocks and section titles, and omits everything else in the book: text paragraphs, figures, and pseudocode.
#
# **If you want to be able to follow what's going on, I recommend reading the notebook side by side with your copy of the book.**
#
# This notebook was generated for TensorFlow 2.6.

# %% [markdown]
# # Generative deep learning

# %% [markdown]
# ## Text generation

# %% [markdown]
# ### A brief history of generative deep learning for sequence generation

# %% [markdown]
# ### How do you generate sequence data?

# %% [markdown]
# ### The importance of the sampling strategy

# %% [markdown]
# **Reweighting a probability distribution to a different temperature**

# %%
import numpy as np
def reweight_distribution(original_distribution, temperature=0.5):
    distribution = np.log(original_distribution) / temperature
    distribution = np.exp(distribution)
    return distribution / np.sum(distribution)

# %% [markdown]
# ### Implementing text generation with Keras

# %% [markdown]
# #### Preparing the data

# %% [markdown]
# **Downloading and uncompressing the IMDB movie reviews dataset**

# %%
# !wget https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -xf aclImdb_v1.tar.gz
# Out:
# --2023-07-11 07:23:32--  https://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘aclImdb_v1.tar.gz’
#
# aclImdb_v1.tar.gz   100%[===================>]  80.23M  18.0MB/s    in 8.0s
#
# 2023-07-11 07:23:41 (10.1 MB/s) - ‘aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# **Creating a dataset from text files (one file = one sample)**

# %%
import tensorflow as tf
from tensorflow import keras
dataset = keras.utils.text_dataset_from_directory(
    directory="aclImdb", label_mode=None, batch_size=256)
dataset = dataset.map(lambda x: tf.strings.regex_replace(x, "<br />", " "))
# Out:
# Found 100006 files belonging to 1 classes.

# %% [markdown]
# **Preparing a `TextVectorization` layer**

# %%
from tensorflow.keras.layers import TextVectorization

sequence_length = 100
vocab_size = 15000
text_vectorization = TextVectorization(
    max_tokens=vocab_size,
    output_mode="int",
    output_sequence_length=sequence_length,
)
text_vectorization.adapt(dataset)

# %% [markdown]
# **Setting up a language modeling dataset**

# %%
def prepare_lm_dataset(text_batch):
    vectorized_sequences = text_vectorization(text_batch)
    x = vectorized_sequences[:, :-1]
    y = vectorized_sequences[:, 1:]
    return x, y

lm_dataset = dataset.map(prepare_lm_dataset, num_parallel_calls=4)

# %% [markdown]
# #### A Transformer-based sequence-to-sequence model

# %%
import tensorflow as tf
from tensorflow.keras import layers

class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, input_dim, output_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=input_dim, output_dim=output_dim)
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=output_dim)
        self.sequence_length = sequence_length
        self.input_dim = input_dim
        self.output_dim = output_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

    def get_config(self):
        config = super(PositionalEmbedding, self).get_config()
        config.update({
            "output_dim": self.output_dim,
            "sequence_length": self.sequence_length,
            "input_dim": self.input_dim,
        })
        return config


class TransformerDecoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
          num_heads=num_heads, key_dim=embed_dim)
        self.attention_2 = layers.MultiHeadAttention(
          num_heads=num_heads, key_dim=embed_dim)
        self.dense_proj = keras.Sequential(
            [layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()
        self.supports_masking = True

    def get_config(self):
        config = super(TransformerDecoder, self).get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1),
             tf.constant([1, 1], dtype=tf.int32)], axis=0)
        return tf.tile(mask, mult)

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(
                mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)
        else:
            padding_mask = mask
        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=causal_mask)
        attention_output_1 = self.layernorm_1(inputs + attention_output_1)
        attention_output_2 = self.attention_2(
            query=attention_output_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        attention_output_2 = self.layernorm_2(
            attention_output_1 + attention_output_2)
        proj_output = self.dense_proj(attention_output_2)
        return self.layernorm_3(attention_output_2 + proj_output)

# %% [markdown]
# **A simple Transformer-based language model**

# %%
from tensorflow.keras import layers
embed_dim = 256
latent_dim = 2048
num_heads = 2

inputs = keras.Input(shape=(None,), dtype="int64")
x = PositionalEmbedding(sequence_length, vocab_size, embed_dim)(inputs)
x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, x)
outputs = layers.Dense(vocab_size, activation="softmax")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="sparse_categorical_crossentropy", optimizer="rmsprop")

# %% [markdown]
# ### A text-generation callback with variable-temperature sampling

# %% [markdown]
# **The text-generation callback**

# %%
import numpy as np

tokens_index = dict(enumerate(text_vectorization.get_vocabulary()))

def sample_next(predictions, temperature=1.0):
    predictions = np.asarray(predictions).astype("float64")
    predictions = np.log(predictions) / temperature
    exp_preds = np.exp(predictions)
    predictions = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, predictions, 1)
    return np.argmax(probas)

class TextGenerator(keras.callbacks.Callback):
    def __init__(self,
                 prompt,
                 generate_length,
                 model_input_length,
                 temperatures=(1.,),
                 print_freq=1):
        self.prompt = prompt
        self.generate_length = generate_length
        self.model_input_length = model_input_length
        self.temperatures = temperatures
        self.print_freq = print_freq
        vectorized_prompt = text_vectorization([prompt])[0].numpy()
        self.prompt_length = np.nonzero(vectorized_prompt == 0)[0][0]

    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.print_freq != 0:
            return
        for temperature in self.temperatures:
            print("== Generating with temperature", temperature)
            sentence = self.prompt
            for i in range(self.generate_length):
                tokenized_sentence = text_vectorization([sentence])
                predictions = self.model(tokenized_sentence)
                next_token = sample_next(
                    predictions[0, self.prompt_length - 1 + i, :]
                )
                sampled_token = tokens_index[next_token]
                sentence += " " + sampled_token
            print(sentence)

prompt = "This movie"
text_gen_callback = TextGenerator(
    prompt,
    generate_length=50,
    model_input_length=sequence_length,
    temperatures=(0.2, 0.5, 0.7, 1., 1.5))

# %% [markdown]
# **Fitting the language model**

# %%
model.fit(lm_dataset, epochs=200, callbacks=[text_gen_callback])
# Out:
# Epoch 1/200
# 391/391 [==============================] - ETA: 0s - loss: 5.9240== Generating with temperature 0.2
# This movie entertainment is not doing from [UNK] [UNK] but piper haunted me had already any good way it sucks for how to say they quite like me and wow that this movie not show to be disney movie this movie is lupino and sometimes they know i can tell a great
# == Generating with temperature 0.5
# This movie but the story has finished watching the plot it circles its first place in 5 you are law are no dreadful rush to be waiting for 2 little girl ship at the [UNK] movie the point for the fact use scenes from these days this movie from it has now
# == Generating with temperature 0.7
# This movie is one of a short and 1 horror film made this bronson very well done when you are used to this for mistakes by departments or stagecoach you would leave it has got people go to wheres you to the plot it quickly hopes if you can all knew such
# == Generating with temperature 1.0
# This movie for pairing me if you see this movie again glad i see all that this truly [UNK] these characters in the emotions and with a bit perhaps the way i love this movie but as a negative at the usual way enjoyed that bruce arts movies so i have to
# == Generating with temperature 1.5
# This movie as awful it seems quite a [UNK] always looked very funny thing its a simple feeling that the every good rating on this terrible the previous people to me is that which dont know serve in my getting funny when dvd features a living the recommended for all were very
# 391/391 [==============================] - 179s 432ms/step - loss: 5.9240
# Epoch 2/200
# 391/391 [==============================] - ETA: 0s - loss: 5.4542== Generating with temperature 0.2
# This movie is not if you are rosalind ridiculous any of the darkness is utter classic much visited i mean nothing to those read your genre being [UNK] and frankly for a sophia noon and it this is guessing this style of the monumental by me his other than burn this is
# == Generating with temperature 0.5
# This movie made a hobby down your viewpoints with a good time it is that it to be restricted about a few times before so much unpredictable should take time period but i have too good job and their [UNK] is the major places in the guys first off with no one
# == Generating with temperature 0.7
# This movie arrived with it starts off their [UNK] brothers who dont have any screens bring out the acting was thoroughly excited about he opened to the mark donkey steadily some poignant rory down to his character is a smug the entire heart of the others are the first appeal off the
# == Generating with temperature 1.0
# This movie has everything on bell is that make it is the best horror in full of my own time period for weeks and early and ta getting a movie was some can set by the words you take from an extremely predictable in [UNK] gives the same time of eighties for
# == Generating with temperature 1.5
# This movie is a great bmovies it is receiving in fact of its not your film again i got me that it is wonderful locales of anything in the acting is very original watch that i must have no idea of a decent served going for lovers store act in your so
# This movie was just one of my life because the movies that i will not completely threatening i was hard to get it out of my life with making out if it would just didnt find it would have to our bold but again this was the book ever wish that it
# == Generating with temperature 0.7
# This movie is brutally [UNK] at a good cast it is way the best and it is very good as good i have high class if you feel as funny times cause it takes it big horn movie on tape [UNK] make it istanbul the right for many bizarre when watching this
# == Generating with temperature 1.0
# This movie is not the worst film it is a weak and it has ever made to deliver the acting sucked so terrible and the plot was quickly special [UNK] is totally misleading it can keep warning [UNK] and special effects are bad i get the plot generally a candle to hear
# == Generating with temperature 1.5
# This movie is a bergmans first movie of fulcis all of the perfect murder which i have much surrealism and the powerful ending was brilliant actor is [UNK] from alan [UNK] is back from [UNK] the direction is a novel but as a wonderfully played the movie he struggles to the price
# 391/391 [==============================] - 168s 429ms/step - loss: 5.0233
# Epoch 9/200
# 391/391 [==============================] - ETA: 0s - loss: 4.9896== Generating with temperature 0.2
# This movie has gets an amusing climatic extensive humor to it the characters and unexpected dialogues beneath a quite floating fourteen years ago that are at the zone from every line [UNK] the actors thrown around script is placed in terms of holes along and clichéd dialog aiming or in the action
# == Generating with temperature 0.5
# This movie has to be tongue in my friend in any movie at first i didnt read the future where it on the audience just finished up there skip hand its pretty good guy appearing in this thing i wont get the other if there were moments however just dont expect more
# == Generating with temperature 0.7
# This movie has nothing while watching an insult to write about ideas and characters and interesting performances and ida isnt much satisfied its its not less character driven rebellion in [UNK] carl [UNK] movie the [UNK] any character development in black crawford her projects that this scheme another role i thought through
# == Generating with temperature 1.0
# This movie tries to understand why do from the writing seems hook could be so simple as hard to spoil to convince you can almost be a boring slow pacing and right almost else and not ring 2 li and pretty early aerial shot but wrong a movie drags great visual [UNK]
# == Generating with temperature 1.5
# This movie looked like yes dirt cheap thrills lame we even called choice school boys decide to happen in english even bother making the hell night like shed movies plot add awful watch wow what else unoriginal storyline or worse than cannibal with a hit early kiss ill [UNK] but stupid and
# 391/391 [==============================] - 168s 430ms/step - loss: 4.9896
# Epoch 10/200
# 391/391 [==============================] - ETA: 0s - loss: 4.9595== Generating with temperature 0.2
# This movie is terrible i havent ever seen of the original or have been done i have seen this movie based on the idea and certainly one person if it was an aging if it was actually somewhat [UNK] is where to be a good and worse and is a serious fans
# == Generating with temperature 0.5
# This movie seems a typical slasher movie about a [UNK] in a cop not heavily [UNK] in the snl and the graphic slow in a twin mother of [UNK] who has turned in aimlessly the young policeman possessed gate who are murdered and there is probably about a massacre the plot is
# == Generating with temperature 0.7
# This movie maintained my intelligence of [UNK] serious and the details of the horror and effects my rating straight you lili gimmick is about the dead but the curse is a [UNK] the [UNK] in the one asks [UNK] of the whole thing on you followed it was watching izo and the
# == Generating with temperature 1.0
# This movie is so [UNK] with random sight then at this movie having another a wide [UNK] useless unnecessary martian [UNK] theater brooklyn myth there is about the meat it the incredibly stupid stiff and so called one it that wont go to [UNK] hundreds of the voice and the story of
# == Generating with temperature 1.5
# This movie was directed by far one of the worst of the night some comedies i have ever made it one awful about every single one was a fond memories in wwi a bad guy into your cannibalistic [UNK] has seen in attendance cannot be said [UNK] budget scifi but after the
# 391/391 [==============================] - 168s 430ms/step - loss: 4.9595
# Epoch 11/200
# 391/391 [==============================] - ETA: 0s - loss: 4.
# == Generating with temperature 1.5
# This movie was ok probably one of the best [UNK] and it must be seen there and though it was very worst of no no action film was not funny terrible the [UNK] this movie ever made in this a [UNK] [UNK] but not a [UNK] the worst nothing else a stupid
# 391/391 [==============================] - 168s 430ms/step - loss: 4.8211
# Epoch 17/200
# 391/391 [==============================] - ETA: 0s - loss: 4.8027== Generating with temperature 0.2
# This movie was really awful the only reason i paid to see this movie much that at all in my money for at one is my office its not really really students about this movie i dont even make watchable to laugh i as usual 80s teen flick coming its not at
# == Generating with temperature 0.5
# This movie is about hong [UNK] the action performed by john [UNK] disappear from the top of all time when his crew uncover the [UNK] gosling is nonsensical the socalled christian [UNK] [UNK] [UNK] [UNK] female spy and how many americans and apache and his costar of the former [UNK] the american
# == Generating with temperature 0.7
# This movie is bad its kinda interesting id like this game where the story is right and [UNK] is when a different because it gets drawn out of it was done too slow and the window sucks the fact that the jokes are all bad the ape further is something about when
# == Generating with temperature 1.0
# This movie had a lot of potential but bad actors were all totally overshadowed by rich people and another one the individual bands in this movie starts out that way outside of kids are that should have i cant act until they tried to hide the way the end up in utter
# == Generating with temperature 1.5
# This movie isnt funny or funny yes but the goal is still funny and [UNK] if you see it has none of them [UNK] movies out of the only needs to watch and jt that seem to far as sean connery and manages to forget it is a mustsee for children i
# 391/391 [==============================] - 168s 430ms/step - loss: 4.8027
# Epoch 18/200
# 391/391 [==============================] - ETA: 0s - loss: 4.7849== Generating with temperature 0.2
# This movie has very predictable and is a lot of dialog weak story lines are bad julia roberts craig [UNK] the movie [UNK] the other better but the will make up instead of a mess well i like any redeeming factor and less about this movie rent this is horrible  remarks
# == Generating with temperature 0.5
# This movie isnt too entertaining to stop flaws youd want to want to change something hip sexy and with our brains out to see lots of onscreen technology could do better then go their sequels have so great even centers around alone sean they associate themselves but remain comical often wonder how
# == Generating with temperature 0.7
# This movie is great from the start to finish orson welles film suddenly stated how does very start the supporting cast [UNK] production immensely jessica alba may not one of jack carson though it is important for other users have any sort of bernard williams who is well enough and ray meets
# == Generating with temperature 1.0
# This movie was kinda funny and though i liked walter matthau went to see the movie i feel as good guys and find out youll want obsessive compulsive and i have to go to enjoy there is beautiful thing david and others this movies and remember seeing jason where are the lead
# == Generating with temperature 1.5
# This movie must for some fun at a [UNK] only i didnt find decent time if its worth buying it instead of courage to find it doesnt take any more fun or vin diesel  grandma love everyone [UNK] [UNK] lovers attempts [UNK] delirious locals meat and [UNK] whose [UNK] [UNK] walters
# 391/391 [==============================] - 168s 430ms/step - loss: 4.7849
# Epoch 19/200
# 391/391 [==============================] - ETA: 0s - loss: 4.7668== Generating with temperature 0.2
# This movie has some flaws in the first terrible script the special effects are lame sound became a couple of the exception of gaping holes are good of time crooked but the characters all over the worst actors started young women is a bikini widmark plays the puppets are laughable the movie
# == Generating with temperature 0.5
# This movie is at sterling farley his installments in the time this year old local 80s i recently watched it was excited phillips at the killer especially [UNK] ever in flashbacks and andy [UNK] with his house in the old invented an actual plot focused on the teacher myself enjoying this movie
# == Generating with temperature 0.7
# This movie was horrible let me up on tv recently profoundly drawn to seeing it because process by these two dexter is receiving pain what a sick bad plot seems to virtually have been a mental asylum poverty row and sometimes fall far and some friends set pieces of work is the
# This movie is so underrated and interesting to nearly every level of movie rock on tv every movie that stayed on tv invasion of all time as for its time ever since in todays early 70s maybe i reviewed it a huge boxoffice [UNK] with the name of a handful of [UNK]
# == Generating with temperature 1.5
# This movie came as a surprise it wasnt a tv movie remade some ideas of the human factor that made science fiction kill the [UNK] storyline or dare the matrix gets an occasional good effort the result is painfully obvious that they end up there was an interesting story giving it such
# 391/391 [==============================] - 169s 432ms/step - loss: 3.9227
# Epoch 76/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9180== Generating with temperature 0.2
# This movie is just nice watching it you get confused waiting for characters to get a laugh we sort of in order to get in the end the way the movie starts of ordinary and the time goes off with the main actor [UNK] in the second one performance [UNK] jack is
# == Generating with temperature 0.5
# This movie is awful the storyline sounded ok and it might be a little off the fact that these actors were [UNK] the director and the characters werent engaging i would never lead me to feel sorry for them so that was likely to make it clear that the story was the
# == Generating with temperature 0.7
# This movie gives you the least a higher message 7 someone [UNK] we all know what we are getting considering our class daily around high in small countries earth such are probably wrong when people start the school [UNK] media drugs give them credit to their own goals a theme park throws
# == Generating with temperature 1.0
# This movie missed the point of the film the large and then came a mixed bag of [UNK] which was meant to be [UNK] was over the head of a few of the subplots the fundamental clash between the two sides of the spectrum is to compare this movie and tarantino the
# == Generating with temperature 1.5
# This movie certainly made in a very realistic manner that william keane shows a new year in argentina he made [UNK] before [UNK] boris karloff and a new actor al pacino john [UNK] and richardson lewis stone is fine by charlton heston as the top of the dead sharon stones over the
# 391/391 [==============================] - 169s 431ms/step - loss: 3.9180
# Epoch 77/200
# 391/391 [==============================] - ETA: 0s - loss: 3.9134== Generating with temperature 0.2
# This movie is a celebration of the [UNK] brand of [UNK] [UNK] [UNK] and [UNK] [UNK] [UNK] from the [UNK] of wwi [UNK] [UNK] in a deal the war that only thou the [UNK] corps beginning of the [UNK] appeared in approximately 23 [UNK] [UNK] during the [UNK] [UNK] are devoted to
# == Generating with temperature 0.5
# This movie had me a smile on my face in it all the horror films and i was bored the movies at night and i was quite convinced that this was the only 8 shark movie i feared it had some good moments my background might feel about this movie were underwater
# == Generating with temperature 0.7
# This movie is my all time favorite hk comedies can carry a few minutes to be laced with the absolute worst or contrived plot the acting by anything hes no character driven action movie cliche and at the very b movies and the story can certainly be better this movie just is
# == Generating with temperature 1.0
# This movie was downright horrible i found it to be the worst part of the movie i remember very well in the end too for the first 30 minutes these folks being [UNK] around this embarrassed watching this movie i dont care if i watch the movie in the court of professor
# == Generating with temperature 1.5
# This movie was only a 2 or 1 im 3 and the women was just too fake i think is a 3 without the prostitutes tell how film equipment or the girls latino males are pretty [UNK] acting wise the guy with a [UNK] accent not one champ i am to [UNK]
# 391/391 [==============================] - 169s 432ms/step - loss: 3.9134
# Epoch 78/200
# 274/391 [====================>.........] - ETA: 47s - loss: 3.9109

# %% [markdown]
# ### Wrapping up

# %% [markdown]
# * You can generate discrete sequence data by training a model to predict the next
# token(s), given previous tokens.
# * In the case of text, such a model is called a language model. It can be based on
# either words or characters.
# * Sampling the next token requires a balance between adhering to what the
# model judges likely, and introducing randomness.
# * One way to handle this is the notion of softmax temperature. Always experiment with different temperatures to find the right one.
